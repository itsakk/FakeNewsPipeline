# %%
import json
import requests
import os
import re

# %%
def get_news_files(news_source, label):
    path = 'C:\\Users\\arman\\Documents\\Bristol_DataScience_MSc\\MSc_Thesis\\FakeNewsNet-master\\code\\fakenewsnet_dataset\\'+news_source+'\\'+label
    os.chdir(path)
    list_news_files = os.listdir(path)
    return list_news_files

def get_data(news_source, label, filename):
    try:
        path = 'C:\\Users\\arman\\Documents\\Bristol_DataScience_MSc\\MSc_Thesis\\FakeNewsNet-master\\code\\fakenewsnet_dataset\\'+news_source+'\\'+label+'\\'+filename
        os.chdir(path)
        f = open('news content.json',)
        data = json.load(f)
        return data
    except:
        pass
    
def save_image(data, filename):
    try:
        response = requests.get(data['top_img'], timeout = 3)
        file = open(re.sub('[a-z-]', '', filename)+'.png', "wb")
        file.write(response.content)
        file.close()
        return 
    except:
        return
    
def main():
    news_sources = ['politifact', 'gossipcop']
    labels = ['fake', 'real']
    for source in news_sources:
        for label in labels:
            list_news_files = get_news_files(source, label)
            for filename in list_news_files:
                print(filename)
                try:
                    data = get_data(source, label, filename)
                    save_image(data, filename)
                except:
                    pass
            print(f'images related to {label} news of {source} collected')

if __name__ == "__main__":
    main()
# Out:
# gossipcop-541230
# gossipcop-561182
# gossipcop-567233
# gossipcop-679264
# gossipcop-681826
# gossipcop-720665
# gossipcop-736743
# gossipcop-752203
# gossipcop-753989
# gossipcop-756594
# gossipcop-759111
# gossipcop-760408
# gossipcop-760656
# gossipcop-769474
# gossipcop-771273
# gossipcop-773997
# gossipcop-774688
# gossipcop-780860
# gossipcop-780888
# gossipcop-781571
# gossipcop-790070
# gossipcop-790695
# gossipcop-791537
# gossipcop-794053
# gossipcop-795008
# gossipcop-796964
# gossipcop-800996
# gossipcop-803477
# gossipcop-805368
# gossipcop-806350
# gossipcop-807937
# gossipcop-809314
# gossipcop-809485
# gossipcop-810105
# gossipcop-812238
# gossipcop-813682
# gossipcop-814011
# gossipcop-817047
# gossipcop-817462
# gossipcop-822709
# gossipcop-828460
# gossipcop-829853
# gossipcop-831504
# gossipcop-831625
# gossipcop-832452
# gossipcop-832997
# gossipcop-833426
# gossipcop-833460
# gossipcop-833797
# gossipcop-833890
# gossipcop-834570
# gossipcop-835068
# ...

# %%
def get_news_files(news_source, label):
    path = 'C:\\Users\\arman\\Documents\\Bristol_DataScience_MSc\\MSc_Thesis\\FakeNewsNet-master\\code\\fakenewsnet_dataset\\'+news_source+'\\'+label
    os.chdir(path)
    list_news_files = os.listdir(path)
    return list_news_files

def get_data(news_source, label, filename):
    try:
        path = 'C:\\Users\\arman\\Documents\\Bristol_DataScience_MSc\\MSc_Thesis\\FakeNewsNet-master\\code\\fakenewsnet_dataset\\'+news_source+'\\'+label+'\\'+filename
        os.chdir(path)
        f = open('news content.json',)
        data = json.load(f)
        return data
    except:
        pass

list_news_files = get_news_files('politifact', 'real')
for file in list_news_files:
    try:
        data = get_data('politifact', 'real', file)
        print(data['movies'])
    except:
        pass
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['https://www.youtube.com/embed/0BJwAQTxp78?enablejsapi=1']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['http://www.youtube.com/v/o8UqQMa7q9Y&hl=en&fs=1&color1=0x2b405b&color2=0x6b8ab6&border=1']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...
